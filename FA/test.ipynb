# %%
import numpy as np
import pandas as pd
from pandas_datareader import data as wb

import matplotlib.pyplot as plt
import fundamentalanalysis as fa

# %%
ticker = "MSFT"
api_key = "f1ae8ba37c1321bd179bbe33dbddc3ef"

# %%
growthFS = fa.financial_statement_growth(ticker, api_key, period="annual")
growthFS
# Out:
#                                             2022      2021      2020  \
# period                                        FY        FY        FY
# revenueGrowth                           0.179561  0.175317  0.136456
# grossProfitGrowth                       0.170591  0.195168  0.168859
# ebitgrowth                              0.192617  0.320191   0.23278
# operatingIncomeGrowth                   0.192617  0.320191   0.23278
# netIncomeGrowth                         0.187152  0.383686  0.128466
# epsgrowth                               0.194581  0.395189  0.138943
# epsdilutedGrowth                        0.198758  0.397569   0.13834
# weightedAverageSharesGrowth            -0.006758 -0.008279 -0.008211
# weightedAverageSharesDilutedGrowth     -0.008938 -0.009762 -0.009029
# dividendsperShareGrowth                 0.105162  0.100543  0.105084
# operatingCashFlowGrowth                 0.160216  0.264771   0.16269
# freeCashFlowGrowth                      0.160929  0.240615  0.182279
# ...

# %%
growthFS.iloc[1] * 100

# %%
growthFS.loc['revenueGrowth']

# %%
revGrowth = growthFS.loc['revenueGrowth'] * 100
revGrowth
# Out:
# 2022    17.956071
# 2021    17.531727
# 2020    13.645574
# 2019     14.02954
# 2018    22.690384
# 2017     5.426629
# 2016    -8.826672
# 2015     7.770087
# 2014     11.54029
# 2013     5.596625
# 2012     5.404401
# 2011    11.937456
# 2010     6.925407
# 2009    -3.282026
# 2008    18.187864
# 2007    15.446457
# 2006    11.294863
# 2005     8.016832
# 2004    14.440613
# 2003    13.474352
# 2002    12.132353
# 2001    10.193413
# 2000     16.25057
# 1999    36.336647
# 1998    27.522451
# 1997    30.988352
# 1996    46.050194
# 1995    27.704883
# 1994    23.874234
# 1993    36.042339
# 1992    49.652815
# 1991    55.771506
# 1990    47.280647
# 1989    36.002031
# 1988    70.800809
# 1987    75.139241
# 1986          0.0
# Name: revenueGrowth, dtype: object

# %%
revGrowth.mean()
# Out:
# 21.91753941040824

# %%
revGrowth.plot(figsize=(8,5))
# plt.gca().invert_xaxis()
plt.show()

# %%
seqRevGrowth = revGrowth
seqRevGrowth = seqRevGrowth.iloc[::-1]
type(seqRevGrowth)
# Out:
# pandas.core.series.Series

# %%
seqRevGrowth.head()
# Out:
# 1986          0.0
# 1987    75.139241
# 1988    70.800809
# 1989    36.002031
# 1990    47.280647
# Name: revenueGrowth, dtype: object

# %%
seqRevGrowth.plot(figsize=(15,6))

plt.show()

# %%
growthFS.head(2)
# Out:
#                    2022      2021      2020      2019      2018      2017  \
# period               FY        FY        FY        FY        FY        FY
# revenueGrowth  0.179561  0.175317  0.136456  0.140295  0.226904  0.054266
#
#                    2016      2015      2014      2013  ...      1995  \
# period               FY        FY        FY        FY  ...        FY
# revenueGrowth -0.088267  0.077701  0.115403  0.055966  ...  0.277049
#
#                    1994      1993      1992      1991      1990     1989  \
# period               FY        FY        FY        FY        FY       FY
# revenueGrowth  0.238742  0.360423  0.496528  0.557715  0.472806  0.36002
#
#                    1988      1987 1986
# period               FY        FY   FY
# revenueGrowth  0.708008  0.751392  0.0
#
# [2 rows x 37 columns]
