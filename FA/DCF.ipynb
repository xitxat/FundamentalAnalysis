# %% [markdown]
# https://site.financialmodelingprep.com/discounted-cash-flow-model/MSFT
#
# https://site.financialmodelingprep.com/developer/docs/dcf-formula/
#
#
# ### FMP API DCF calculation:
#
# Market Cap = Weigted Average Shares Outstanding Diluted * Stock Price
#
# Enterprise Value NB = Market Cap + Long Term Debt + Short Term Debt
#
# Equity Value = Enterprise Value NB - Net Debt
#
# DCF = Equity Value / Weigted Average Shares Outstanding Diluted
#
# Stock Beta = Monthly price change of stock relative to the monthly price change of the S&P500 (COV(Rs,RM) / VAR(Rm))

# %%
import pandas as pd
import fundamentalanalysis as fa


ticker = "MSFT"
api_key = "f1ae8ba37c1321bd179bbe33dbddc3ef"



# dcf =  fa.discounted_cash_flow(ticker, api_key, ) # ANNUAL
# dcf.round(2)

# %%
key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual",  limit = 12)
key_metrics_annually
# Out:
#                                                  2022                  2021  \
# period                                             FY                    FY
# revenuePerShare                             26.450107             22.272161
# netIncomePerShare                            9.703575               8.11859
# operatingCashFlowPerShare                   11.877668             10.168279
# freeCashFlowPerShare                         8.691169              7.435802
# cashPerShare                                13.973986             17.269644
# bookValuePerShare                           22.217449             18.813833
# tangibleBookValuePerShare                   11.702241             11.193454
# shareholdersEquityPerShare                  22.217449             18.813833
# interestDebtPerShare                         8.448906              9.291242
# marketCap                               2104427040000  2150215797923.900146
# ...

# %%
entreprise_value = fa.enterprise(ticker, api_key, period='week')
entreprise_value
# Out:
#                                       2022                  2021  \
# symbol                                MSFT                  MSFT
# stockPrice                          280.74            284.910004
# numberOfShares                  7496000000            7547000000
# marketCapitalization         2104427040000  2150215797923.900146
# minusCashAndCashEquivalents    13931000000           14224000000
# addTotalDebt                   61270000000           67775000000
# enterpriseValue              2151766040000  2203766797923.900391
#
#                                       2020                  2019  \
# symbol                                MSFT                  MSFT
# stockPrice                      203.899994            140.350006
# numberOfShares                  7610000000            7673000000
# marketCapitalization         1551678953579  1076905596805.300049
# minusCashAndCashEquivalents    13576000000           11356000000
# ...
